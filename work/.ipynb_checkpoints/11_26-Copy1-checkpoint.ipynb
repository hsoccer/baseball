# %%
import pandas as pd
import numpy as np
import re
import os, sys
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter, defaultdict
from itertools import product
from scipy import stats

# %matplotlib inline
plt.style.use('ggplot')
#plt.style.use('seaborn-pastel')
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm_notebook as tq

sys.path.append("..")
from utils.util_functions import *

# %% [markdown]
# # MLB

# %%
event_df = make_df(data_dir=DETAIL_DATA_DIR_MLB)
df_2017 = make_df(end=1944417, data_dir=DETAIL_DATA_DIR_MLB)
df_2018 = make_df(start=1944417, data_dir=DETAIL_DATA_DIR_MLB)
files = os.listdir(DETAIL_DATA_DIR_MLB)[1:]
names = pd.Series(files).apply(lambda x: int(x.split(".")[0]))
files_2017 = names[names<=1944417].apply(lambda x: str(x)+".csv")
files_2018 = names[names>1944417].apply(lambda x: str(x)+".csv")
column = "得点"
teams_mlb = list(set(pd.read_csv(os.path.join(SCORE_DATA_DIR_MLB, "score_mlb.csv"), encoding="cp932", index_col=0).表チーム))
teams_mlb.remove("ア・リーグ")

# %%
event_df[]
# Out:
#              状況   打順       打者     結果  アウト  裏得点  表得点 イニング   表裏   攻撃チーム
# 0          0000    1      ホルト  空振り三振    1    0    0    1    表   Rソックス
# 1          1000    2    ペドロイア  空振り三振    2    0    0    1    表   Rソックス
# 2          2000    3  ベニンテンディ     四球    2    0    0    1    表   Rソックス
# 3          2100    4    モアランド   右フライ    3    0    0    1    表   Rソックス
# 4          3000    1      NaN    NaN    3  NaN  NaN    1  NaN   Rソックス
# 5          0000    1    キンズラー    中安打    0    0    0    1    裏   タイガース
# 6          0100    2   カステラノス     四球    0    0    0    1    裏   タイガース
# 7          0110    3     カブレラ    右邪飛    1    0    0    1    裏   タイガース
# 8          1101    4   マルティネス    左犠飛    2    1    0    1    裏   タイガース
# 9          2100    5    アップトン     四球    2    1    0    1    裏   タイガース
# 10         2110    6     コリンズ  空振り三振    3    1    0    1    裏   タイガース
# 11         3000    1      NaN    NaN    3  NaN  NaN    1  NaN   タイガース
# 12         0000    5      ヤング   右フライ    1    1    0    2    表   Rソックス
# 13         1000    6   ブラッドリー  中ライナー    2    1    0    2    表   Rソックス
# 14         2000    7      レオン    二ゴロ    3    1    0    2    表   Rソックス
# 15         3000    2      NaN    NaN    3  NaN  NaN    2  NaN   Rソックス
# 16         0000    7     マキャン    三ゴロ    1    1    0    2    裏   タイガース
# 17         1000    8    ジョーンズ    中安打    1    1    0    2    裏   タイガース
# 18         1100    9   イグレシアス  二ゴロ併殺    3    1    0    2    裏   タイガース
# 19         0000    8    サンドバル  空振り三振    1    1    0    3    表   Rソックス
# 20         1000    9   ヘルナンデス    一ゴロ    2    1    0    3    表   Rソックス
# 21         2000    1      ホルト    一安打    2    1    0    3    表   Rソックス
# 22         2100    2    ペドロイア    左安打    2    1    0    3    表   Rソックス
# 23         2110    3  ベニンテンディ     死球    2    1    0    3    表   Rソックス
# 24         2111    4    モアランド  空振り三振    3    1    0    3    表   Rソックス
# 25         3000    3      NaN    NaN    3  NaN  NaN    3  NaN   Rソックス
# 26         0000    1    キンズラー     死球    0    1    0    3    裏   タイガース
# 27         0100    2   カステラノス  遊ゴロ併殺    2    1    0    3    裏   タイガース
# 28         2000    3     カブレラ  中ライナー    3    1    0    3    裏   タイガース
# 29         3000    3      NaN    NaN    3  NaN  NaN    3  NaN   タイガース
# ...         ...  ...      ...    ...  ...  ...  ...  ...  ...     ...
# 431417     3000    6      NaN    NaN    3  NaN  NaN    6  NaN     カブス
# 431418     0000    5     スクープ    三ゴロ    1    1    1    7    表  ブリュワーズ
# 431419     1000    6   ムスターカス    三ゴロ    2    1    1    7    表  ブリュワーズ
# 431420     2000    7      クラツ    二ゴロ    3    1    1    7    表  ブリュワーズ
# 431421     3000    7      NaN    NaN    3  NaN  NaN    7  NaN  ブリュワーズ
# 431422     0000    4       リゾ    二ゴロ    1    1    1    7    裏     カブス
# 431423     1000    5   ブライアント  空振り三振    2    1    1    7    裏     カブス
# 431424     2000    6     ラステラ    二ゴロ    3    1    1    7    裏     カブス
# 431425     3000    7      NaN    NaN    3  NaN  NaN    7  NaN     カブス
# 431426     0000    8     アルシア    中安打    0    1    1    8    表  ブリュワーズ
# 431427     0100    9     サンタナ   左二塁打    0    1    1    8    表  ブリュワーズ
# 431428     0011    1      ケーン    中安打    0    1    2    8    表  ブリュワーズ
# 431429     0101    2     イエリチ  空振り三振    1    1    2    8    表  ブリュワーズ
# 431430     1101    3     ブラウン    中安打    1    1    3    8    表  ブリュワーズ
# 431431     1001    4    アギュラー   左フライ    3    1    3    8    表  ブリュワーズ
# 431432     0000    7    ヘイワード  見逃し三振    1    1    3    8    裏     カブス
# 431433     1000    8     アルモラ  二ライナー    2    1    3    8    裏     カブス
# 431434     2000    9   コントレラス  空振り三振    3    1    3    8    裏     カブス
# 431435     3000    8      NaN    NaN    3  NaN  NaN    8  NaN     カブス
# 431436     0000    5     スクープ    三ゴロ    1    1    3    9    表  ブリュワーズ
# 431437     1000    6   ムスターカス    中安打    1    1    3    9    表  ブリュワーズ
# 431438     1100    7      クラツ    一邪飛    2    1    3    9    表  ブリュワーズ
# 431439     2100    8     アルシア    左安打    2    1    3    9    表  ブリュワーズ
# 431440     2110    9      ショー    捕ゴロ    3    1    3    9    表  ブリュワーズ
# 431441     3000    9      NaN    NaN    3  NaN  NaN    9  NaN  ブリュワーズ
# 431442     0000    1    マーフィー  空振り三振    1    1    3    9    裏     カブス
# 431443     1000    2    ゾブリスト   右フライ    2    1    3    9    裏     カブス
# 431444     2000    3      バエス    中安打    2    1    3    9    裏     カブス
# 431445     2010    4       リゾ   右フライ    3    1    3    9    裏     カブス
# 431446  GAMESET  NaN      NaN    NaN  NaN  NaN  NaN  NaN  NaN     NaN
#
# [431447 rows x 10 columns]

# %%
df = event_df[event_df.攻撃チーム==team]
team = "Rソックス"
columns = list(df.columns)
case_index = columns.index("状況")
try:
    inning_index = columns.index("イニング")
except:
    inning_index = columns.index("回")
top_index = columns.index("表得点")
bot_index = columns.index("裏得点")

inning_list = []
for inning in range(18):
    curr_inning_list = []
    for i in range(len(df)):
        if df.iloc[i, case_index] == "GAMESET":
            continue
        if int(df.iloc[i, inning_index].split("回")[0]) == inning + 1:
            try:
                curr_inning_list.append((df.iloc[i, case_index], abs(int(df.iloc[i, top_index])-int(df.iloc[i, bot_index]))))
            except:
                curr_inning_list.append((df.iloc[i, case_index], np.nan))
    inning_list.append(curr_inning_list)

# %%
pd.DataFrame(inning_list[6]).describe()
# Out:
#                  1
# count  1432.000000
# mean      3.177374
# std       2.552174
# min       0.000000
# 25%       1.000000
# 50%       3.000000
# 75%       5.000000
# max      14.000000

# %%
team = "Rソックス"
df = event_df[event_df.攻撃チーム==team]
triple = make_inning_triple(make_inning_list(df, score_end=4))
lst = make_flattened_list(triple)

# %%
len(triple)
# Out:
# 18

# %%
df = pd.DataFrame(lst)
score_diff = df[1].apply(lambda x: x[1])
df = df.applymap(lambda x: x[0])
df["点差"] = score_diff
df_with_score = df[(df[0]!="3000") & (df[1]!="3000")]

# %%
len(df_with_score[df_with_score.点差<=1][[0, 1, 2]].values.tolist())
# Out:
# 4558

# %% [markdown]
# # 回点差指定せず、流れのいい時だけ

# %%
diffs = []
stds = []
for team in teams_mlb:
    df = event_df[event_df.攻撃チーム==team]
    triple = make_inning_triple(make_inning_list(df, score_end=4))
    lst = make_flattened_list(triple[:])
    df = pd.DataFrame(lst)
    score_diff = df[1].apply(lambda x: x[1])
    df = df.applymap(lambda x: x[0])
    df["点差"] = score_diff
    df_with_score = df[(df[0]!="3000") & (df[1]!="3000")]
    improved_lst = [elem for elem in df_with_score[df_with_score.点差<=30][[0, 1, 2]].values.tolist() if is_improved(elem[0], elem[1])]
    # H(St+1 | St, St-1)
    second_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[0, 1]].values)
    # H(St+1 | St)
    first_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[1]].values)
    std = make_score_df_mlb(team).describe()[column]["std"] / make_score_df_mlb(team).describe()[column]["mean"]
    diffs.append(second_cond_entropy-first_cond_entropy)
    stds.append(std)
    print(team, second_cond_entropy-first_cond_entropy, std)
# Out:
# パイレーツ -0.07452107769433924 0.713864249192
# マリナーズ -0.07216476315211118 0.668948069586
# レイズ -0.06608716381612556 0.70014369491
# ツインズ -0.07334575888129669 0.649470212774
# メッツ -0.06713829108721425 0.735159694044
# Rソックス -0.07997286448271801 0.669210021299
# タイガース -0.07310385778310247 0.72243695297
# インディアンス -0.08068603349086967 0.709479335467
# カージナルス -0.08090705754474259 0.668960338682
# アストロズ -0.07002998302764718 0.684975274055
# ジャイアンツ -0.08098646435742474 0.737955073316
# レンジャーズ -0.08768508268172637 0.714067340083
# ブリュワーズ -0.07547572526071189 0.670083659328
# ロイヤルズ -0.07473927699379646 0.757228903468
# Dバックス -0.08169983095402245 0.708102395369
# マーリンズ -0.08602634396039033 0.745161351662
# パドレス -0.07762289288740254 0.668453678081
# エンゼルス -0.07161647836365015 0.692139970806
# レッズ -0.08028185490385153 0.678095136226
# ヤンキース -0.06017910723664688 0.61072599013
# ロッキーズ -0.0729843569532238 0.6973869369
# ナショナルズ -0.07169169869566883 0.795189195443
# ブレーブス -0.08315309778553459 0.70938418131
# カブス -0.07881846393753245 0.763224672511
# オリオールズ -0.08008719152795907 0.781906801829
# アスレチックス -0.06518569477223801 0.640292515595
# ドジャース -0.07226038015622471 0.697131500955
# ブルージェイズ -0.07927777352135612 0.666022782951
# Wソックス -0.07454791956603612 0.720786613389
# フィリーズ -0.07432567212303232 0.72758841746

# %%
import statsmodels.api as sm

plt.figure(figsize=(12, 6))

nsample = len(diffs)
X = np.column_stack((np.repeat(1, nsample), diffs))

model = sm.OLS(stds, X)
results = model.fit()

a, b = results.params

plt.scatter(diffs, stds)
plt.plot(diffs, a+b*np.array(diffs))
plt.xlabel("エントロピー差")
plt.ylabel("得点の変動係数")
plt.text(x=-0.062, y=0.78, s="p値 : "+str(results.pvalues[1])[:7], fontsize=15)
plt.show()

# %% [markdown]
# # 5回以降だけ考えて点差気にせず・流れのいい時だけ

# %%
diffs = []
stds = []
for team in teams_mlb:
    df = event_df[event_df.攻撃チーム==team]
    triple = make_inning_triple(make_inning_list(df, score_end=4))
    lst = make_flattened_list(triple[4:])
    df = pd.DataFrame(lst)
    score_diff = df[1].apply(lambda x: x[1])
    df = df.applymap(lambda x: x[0])
    df["点差"] = score_diff
    df_with_score = df[(df[0]!="3000") & (df[1]!="3000")]
    improved_lst = [elem for elem in df_with_score[df_with_score.点差<=30][[0, 1, 2]].values.tolist() if is_improved(elem[0], elem[1])]
    # H(St+1 | St, St-1)
    second_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[0, 1]].values)
    # H(St+1 | St)
    first_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[1]].values)
    std = make_score_df_mlb(team).describe()[column]["std"] / make_score_df_mlb(team).describe()[column]["mean"]
    diffs.append(second_cond_entropy-first_cond_entropy)
    stds.append(std)
    print(team, second_cond_entropy-first_cond_entropy, std)
# Out:
# パイレーツ -0.10514718982897042 0.713864249192
# マリナーズ -0.10557307008026706 0.668948069586
# レイズ -0.09167615259192452 0.70014369491
# ツインズ -0.10240223579728003 0.649470212774
# メッツ -0.09997064821603185 0.735159694044
# Rソックス -0.10102953331552467 0.669210021299
# タイガース -0.10050440362492141 0.72243695297
# インディアンス -0.10590184095849908 0.709479335467
# カージナルス -0.10635357148576263 0.668960338682
# アストロズ -0.10664447322098347 0.684975274055
# ジャイアンツ -0.11314746705516887 0.737955073316
# レンジャーズ -0.11668338427485692 0.714067340083
# ブリュワーズ -0.09620898201481509 0.670083659328
# ロイヤルズ -0.10693576165622742 0.757228903468
# Dバックス -0.1168725717071375 0.708102395369
# マーリンズ -0.11442434406972035 0.745161351662
# パドレス -0.09612666791465863 0.668453678081
# エンゼルス -0.11203743240570452 0.692139970806
# レッズ -0.10147312665568231 0.678095136226
# ヤンキース -0.09541920171942397 0.61072599013
# ロッキーズ -0.10074595217861448 0.6973869369
# ナショナルズ -0.10812917126373645 0.795189195443
# ブレーブス -0.11525116451821704 0.70938418131
# カブス -0.10377490054204186 0.763224672511
# オリオールズ -0.10592093491241039 0.781906801829
# アスレチックス -0.09176168760296255 0.640292515595
# ドジャース -0.10601187224721142 0.697131500955
# ブルージェイズ -0.11881588362054618 0.666022782951
# Wソックス -0.09013105327608129 0.720786613389
# フィリーズ -0.10492183023064738 0.72758841746

# %%
import statsmodels.api as sm

plt.figure(figsize=(12, 6))

nsample = len(diffs)
X = np.column_stack((np.repeat(1, nsample), diffs))

model = sm.OLS(stds, X)
results = model.fit()

a, b = results.params

plt.scatter(diffs, stds)
plt.plot(diffs, a+b*np.array(diffs))
plt.xlabel("エントロピー差")
plt.ylabel("得点の変動係数")
plt.text(x=-0.092, y=0.78, s="p値 : "+str(results.pvalues[1])[:7], fontsize=15)
plt.show()

# %% [markdown]
# # 回を気にせず4点差いない・流れがいい時

# %%
diffs = []
stds = []
for team in teams_mlb:
    df = event_df[event_df.攻撃チーム==team]
    triple = make_inning_triple(make_inning_list(df, score_end=4))
    lst = make_flattened_list(triple[:])
    df = pd.DataFrame(lst)
    score_diff = df[1].apply(lambda x: x[1])
    df = df.applymap(lambda x: x[0])
    df["点差"] = score_diff
    df_with_score = df[(df[0]!="3000") & (df[1]!="3000")]
    improved_lst = [elem for elem in df_with_score[df_with_score.点差<=4][[0, 1, 2]].values.tolist() if is_improved(elem[0], elem[1])]
    # H(St+1 | St, St-1)
    second_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[0, 1]].values)
    # H(St+1 | St)
    first_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[1]].values)
    std = make_score_df_mlb(team).describe()[column]["std"] / make_score_df_mlb(team).describe()[column]["mean"]
    diffs.append(second_cond_entropy-first_cond_entropy)
    stds.append(std)
    print(team, second_cond_entropy-first_cond_entropy, std)
# Out:
# パイレーツ -0.08443182896682089 0.713864249192
# マリナーズ -0.07604239696432424 0.668948069586
# レイズ -0.07174461884520822 0.70014369491
# ツインズ -0.07788711363137901 0.649470212774
# メッツ -0.07591493801863614 0.735159694044
# Rソックス -0.08783311675862837 0.669210021299
# タイガース -0.0815030321123742 0.72243695297
# インディアンス -0.08346642719079922 0.709479335467
# カージナルス -0.08634367503942908 0.668960338682
# アストロズ -0.07161266796617971 0.684975274055
# ジャイアンツ -0.08473121423147534 0.737955073316
# レンジャーズ -0.09139970872321035 0.714067340083
# ブリュワーズ -0.07687700862500568 0.670083659328
# ロイヤルズ -0.08005432838931315 0.757228903468
# Dバックス -0.09029492860748034 0.708102395369
# マーリンズ -0.09049111494303164 0.745161351662
# パドレス -0.08640010894465133 0.668453678081
# エンゼルス -0.08042564454641221 0.692139970806
# レッズ -0.08458663715409731 0.678095136226
# ヤンキース -0.06682244679950022 0.61072599013
# ロッキーズ -0.08335433611744225 0.6973869369
# ナショナルズ -0.07614798740106155 0.795189195443
# ブレーブス -0.08449493964697519 0.70938418131
# カブス -0.08114060233608189 0.763224672511
# オリオールズ -0.08449826816863748 0.781906801829
# アスレチックス -0.07142226571569754 0.640292515595
# ドジャース -0.07336966846102744 0.697131500955
# ブルージェイズ -0.08402585907501736 0.666022782951
# Wソックス -0.07735303323958753 0.720786613389
# フィリーズ -0.07873908073489799 0.72758841746

# %%
import statsmodels.api as sm

plt.figure(figsize=(12, 6))

nsample = len(diffs)
X = np.column_stack((np.repeat(1, nsample), diffs))

model = sm.OLS(stds, X)
results = model.fit()

a, b = results.params

plt.scatter(diffs, stds)
plt.plot(diffs, a+b*np.array(diffs))
plt.xlabel("エントロピー差")
plt.ylabel("得点の変動係数")
plt.text(x=-0.067, y=0.78, s="p値 : "+str(results.pvalues[1])[:7], fontsize=15)
plt.show()

# %% [markdown]
# # 5回以降の4点差いないの状況で、流れがいい時

# %%
diffs = []
stds = []
for team in teams_mlb:
    df = event_df[event_df.攻撃チーム==team]
    triple = make_inning_triple(make_inning_list(df, score_end=4))
    lst = make_flattened_list(triple[4:])
    df = pd.DataFrame(lst)
    score_diff = df[1].apply(lambda x: x[1])
    df = df.applymap(lambda x: x[0])
    df["点差"] = score_diff
    df_with_score = df[(df[0]!="3000") & (df[1]!="3000")]
    improved_lst = [elem for elem in df_with_score[df_with_score.点差<=4][[0, 1, 2]].values.tolist() if is_improved(elem[0], elem[1])]
    # H(St+1 | St, St-1)
    second_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[0, 1]].values)
    # H(St+1 | St)
    first_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[1]].values)
    std = make_score_df_mlb(team).describe()[column]["std"] / make_score_df_mlb(team).describe()[column]["mean"]
    diffs.append(second_cond_entropy-first_cond_entropy)
    stds.append(std)
    print(team, second_cond_entropy-first_cond_entropy, std)
# Out:
# パイレーツ -0.11203980621917564 0.713864249192
# マリナーズ -0.11463112102196638 0.668948069586
# レイズ -0.10135734901887039 0.70014369491
# ツインズ -0.11295681807837887 0.649470212774
# メッツ -0.11274865403155987 0.735159694044
# Rソックス -0.1089538349949919 0.669210021299
# タイガース -0.11441927199679025 0.72243695297
# インディアンス -0.10772344607858919 0.709479335467
# カージナルス -0.1172664010351041 0.668960338682
# アストロズ -0.10608190446227495 0.684975274055
# ジャイアンツ -0.12493546826891233 0.737955073316
# レンジャーズ -0.13084055845748654 0.714067340083
# ブリュワーズ -0.09001101741938156 0.670083659328
# ロイヤルズ -0.11789082586681765 0.757228903468
# Dバックス -0.13302299370124038 0.708102395369
# マーリンズ -0.13103996666450923 0.745161351662
# パドレス -0.10604653506881956 0.668453678081
# エンゼルス -0.13259135068886696 0.692139970806
# レッズ -0.11174145754362952 0.678095136226
# ヤンキース -0.09827959944721965 0.61072599013
# ロッキーズ -0.10584672488960001 0.6973869369
# ナショナルズ -0.11651234745903372 0.795189195443
# ブレーブス -0.12717656492698692 0.70938418131
# カブス -0.11197632443064132 0.763224672511
# オリオールズ -0.11863766613870297 0.781906801829
# アスレチックス -0.09944451936115106 0.640292515595
# ドジャース -0.1083594685752387 0.697131500955
# ブルージェイズ -0.12614037093833996 0.666022782951
# Wソックス -0.09777082518432323 0.720786613389
# フィリーズ -0.11455693330625705 0.72758841746

# %%
import statsmodels.api as sm

plt.figure(figsize=(12, 6))

nsample = len(diffs)
X = np.column_stack((np.repeat(1, nsample), diffs))

model = sm.OLS(stds, X)
results = model.fit()

a, b = results.params

plt.scatter(diffs, stds)
plt.plot(diffs, a+b*np.array(diffs))
plt.xlabel("エントロピー差")
plt.ylabel("得点の変動係数")
plt.text(x=-0.095, y=0.78, s="p値 : "+str(results.pvalues[1])[:7], fontsize=15)
plt.show()

# %% [markdown]
# # 5回以降の4点差いないの状況、流れの良し悪しは見てない

# %%
diffs = []
stds = []
for team in teams_mlb:
    df = event_df[event_df.攻撃チーム==team]
    triple = make_inning_triple(make_inning_list(df, score_end=4))
    lst = make_flattened_list(triple[4:])
    df = pd.DataFrame(lst)
    score_diff = df[1].apply(lambda x: x[1])
    df = df.applymap(lambda x: x[0])
    df["点差"] = score_diff
    df_with_score = df[(df[0]!="3000") & (df[1]!="3000")]
    improved_lst = df_with_score[df_with_score.点差<=2][[0, 1, 2]].values.tolist()
    #improved_lst = [elem for elem in df_with_score[df_with_score.点差<=2][[0, 1, 2]].values.tolist() if is_improved(elem[0], elem[1])]
    # H(St+1 | St, St-1)
    second_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[0, 1]].values)
    # H(St+1 | St)
    first_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[1]].values)
    std = make_score_df_mlb(team).describe()[column]["std"] / make_score_df_mlb(team).describe()[column]["mean"]
    diffs.append(second_cond_entropy-first_cond_entropy)
    stds.append(std)
    print(team, second_cond_entropy-first_cond_entropy, std)
# Out:
# パイレーツ -0.16562095965149037 0.713864249192
# マリナーズ -0.15195894563062406 0.668948069586
# レイズ -0.15037930413195344 0.70014369491
# ツインズ -0.14360194025415618 0.649470212774
# メッツ -0.14682713206462017 0.735159694044
# Rソックス -0.15788449217647083 0.669210021299
# タイガース -0.17015343617300305 0.72243695297
# インディアンス -0.14134938763190652 0.709479335467
# カージナルス -0.15608452077658397 0.668960338682
# アストロズ -0.1613815289144669 0.684975274055
# ジャイアンツ -0.13465341332248348 0.737955073316
# レンジャーズ -0.17493609946344524 0.714067340083
# ブリュワーズ -0.1342532478108236 0.670083659328
# ロイヤルズ -0.15208514178201593 0.757228903468
# Dバックス -0.16007732999127056 0.708102395369
# マーリンズ -0.17846807846459134 0.745161351662
# パドレス -0.15106817280862606 0.668453678081
# エンゼルス -0.16610001974051336 0.692139970806
# レッズ -0.18367349156015722 0.678095136226
# ヤンキース -0.14835470414827823 0.61072599013
# ロッキーズ -0.1543779395733771 0.6973869369
# ナショナルズ -0.1590095058549723 0.795189195443
# ブレーブス -0.159437620155094 0.70938418131
# カブス -0.1519782845769293 0.763224672511
# オリオールズ -0.139475724410139 0.781906801829
# アスレチックス -0.15006475274023412 0.640292515595
# ドジャース -0.14439626871005107 0.697131500955
# ブルージェイズ -0.15615530836097502 0.666022782951
# Wソックス -0.14991735305360843 0.720786613389
# フィリーズ -0.1457464400266284 0.72758841746

# %%
    
import statsmodels.api as sm

plt.figure(figsize=(12, 6))

nsample = len(diffs)
X = np.column_stack((np.repeat(1, nsample), diffs))

model = sm.OLS(stds, X)
results = model.fit()

a, b = results.params

plt.scatter(diffs, stds)
plt.plot(diffs, a+b*np.array(diffs))
plt.xlabel("エントロピー差")
plt.ylabel("得点の変動係数")
plt.text(x=-0.138, y=0.78, s="p値 : "+str(results.pvalues[1])[:7], fontsize=15)
plt.show()

# %% [markdown]
# #

# %%
diffs = []
stds = []
"""
for team in teams_mlb:
    df = df_2017[df_2017.攻撃チーム==team]
    triple = make_inning_triple(make_inning_list(df, score_end=4))
    lst = make_flattened_list(triple[4:])
    df = pd.DataFrame(lst)
    score_diff = df[1].apply(lambda x: x[1])
    df = df.applymap(lambda x: x[0])
    df["点差"] = score_diff
    df_with_score = df[(df[0]!="3000") & (df[1]!="3000")]
    improved_lst = [elem for elem in df_with_score[df_with_score.点差<=4][[0, 1, 2]].values.tolist() if is_improved(elem[0], elem[1])]
    # H(St+1 | St, St-1)
    second_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[0, 1]].values)
    # H(St+1 | St)
    first_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[1]].values)
    std = make_score_df_mlb(team, 2017).describe()[column]["std"] / make_score_df_mlb(team, 2017).describe()[column]["mean"]
    diffs.append(second_cond_entropy-first_cond_entropy)
    stds.append(std)
    print(team, second_cond_entropy-first_cond_entropy, std)
"""
for team in teams_mlb:
    df = df_2018[df_2018.攻撃チーム==team]
    triple = make_inning_triple(make_inning_list(df, score_end=4))
    lst = make_flattened_list(triple[4:])
    df = pd.DataFrame(lst)
    score_diff = df[1].apply(lambda x: x[1])
    df = df.applymap(lambda x: x[0])
    df["点差"] = score_diff
    df_with_score = df[(df[0]!="3000") & (df[1]!="3000")]
    improved_lst = [elem for elem in df_with_score[df_with_score.点差<=4][[0, 1, 2]].values.tolist() if is_improved(elem[0], elem[1])]
    # H(St+1 | St, St-1)
    second_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[0, 1]].values)
    # H(St+1 | St)
    first_cond_entropy = cond_entropy(pd.DataFrame(improved_lst)[2].values, pd.DataFrame(improved_lst)[[1]].values)
    std = make_score_df_mlb(team, 2018).describe()[column]["std"] / make_score_df_mlb(team, 2018).describe()[column]["mean"]
    diffs.append(second_cond_entropy-first_cond_entropy)
    stds.append(std)
    print(team, second_cond_entropy-first_cond_entropy, std)
# Out:
# パイレーツ -0.1300569695952718 0.694631315943
# マリナーズ -0.1372915426992911 0.651219045998
# レイズ -0.11710296253478658 0.722119648926
# ツインズ -0.15688016163827978 0.639182765683
# メッツ -0.14498859744678505 0.802488858453
# Rソックス -0.16376542776707081 0.667728044921
# タイガース -0.13510989120740602 0.752482662379
# インディアンス -0.13770057336686614 0.726463434687
# カージナルス -0.1246180457521997 0.670715947561
# アストロズ -0.13729729178705208 0.654168783787
# ジャイアンツ -0.12981397513849346 0.733145630832
# レンジャーズ -0.16147737029228404 0.779277092863
# ブリュワーズ -0.11308780598829982 0.700645228329
# ロイヤルズ -0.13384828510545121 0.702884289545
# Dバックス -0.16005565272546507 0.71856002575
# マーリンズ -0.12228019396686429 0.733353859821
# パドレス -0.11853647246419596 0.668012755947
# エンゼルス -0.16301701442272254 0.726874887421
# レッズ -0.13819143362943764 0.699232763933
# ヤンキース -0.1261654956649778 0.547909769625
# ロッキーズ -0.13292126832018525 0.6754229857
# ナショナルズ -0.1545945693296198 0.815253052144
# ブレーブス -0.14374555499964803 0.698804842567
# カブス -0.15796099411866882 0.769607655658
# オリオールズ -0.16531627283120365 0.848146059485
# アスレチックス -0.12264443224314947 0.670510497596
# ドジャース -0.12646511696165064 0.752206340683
# ブルージェイズ -0.1614794139029856 0.678415649609
# Wソックス -0.1407147112518321 0.693906187087
# フィリーズ -0.134242715138718 0.774675633336

# %%
    
import statsmodels.api as sm

plt.figure(figsize=(12, 6))

nsample = len(diffs)
X = np.column_stack((np.repeat(1, nsample), diffs))

model = sm.OLS(stds, X)
results = model.fit()

a, b = results.params

plt.scatter(diffs, stds)
plt.plot(diffs, a+b*np.array(diffs))
plt.xlabel("エントロピー差")
plt.ylabel("得点の変動係数")
plt.text(x=-0.138, y=0.78, s="p値 : "+str(results.pvalues[1])[:7], fontsize=15)
plt.show()

# %%
pd.DataFrame([diffs, stds, teams_mlb]).T.sort_values(0)
# Out:
#            0         1        2
# 24 -0.165316  0.848146   オリオールズ
# 5  -0.163765  0.667728    Rソックス
# 17 -0.163017  0.726875    エンゼルス
# 27 -0.161479  0.678416  ブルージェイズ
# 11 -0.161477  0.779277   レンジャーズ
# 14 -0.160056   0.71856    Dバックス
# 23 -0.157961  0.769608      カブス
# 3   -0.15688  0.639183     ツインズ
# 21 -0.154595  0.815253   ナショナルズ
# 4  -0.144989  0.802489      メッツ
# 22 -0.143746  0.698805    ブレーブス
# 28 -0.140715  0.693906    Wソックス
# 18 -0.138191  0.699233      レッズ
# 7  -0.137701  0.726463  インディアンス
# 9  -0.137297  0.654169    アストロズ
# 1  -0.137292  0.651219    マリナーズ
# 6   -0.13511  0.752483    タイガース
# 29 -0.134243  0.774676    フィリーズ
# 13 -0.133848  0.702884    ロイヤルズ
# 20 -0.132921  0.675423    ロッキーズ
# 0  -0.130057  0.694631    パイレーツ
# 10 -0.129814  0.733146   ジャイアンツ
# 26 -0.126465  0.752206    ドジャース
# 19 -0.126165   0.54791    ヤンキース
# 8  -0.124618  0.670716   カージナルス
# 25 -0.122644   0.67051  アスレチックス
# 15  -0.12228  0.733354    マーリンズ
# 16 -0.118536  0.668013     パドレス
# 2  -0.117103   0.72212      レイズ
# 12 -0.113088  0.700645   ブリュワーズ

# %%
# %%latex
#
# $$
#     \text{エントロピー差} = H(S_{t+1}|S_{t}, S_{t-1}) - H(S_{t+1}|S_{t})
# $$
# Out:
# $$
#     \text{エントロピー差} = H(S_{t+1}|S_{t}, S_{t-1}) - H(S_{t+1}|S_{t})
# $$
